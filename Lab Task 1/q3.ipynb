# %%
std_record={}
for i in range(3):
 name=input("Enter student name: " )
 marks=int(input("Enter marks: "))
 std_record[name]=marks

print("\nStudent Records:")

for name,marks in std_record.items():
  print(name,":",marks)
# Out:
# Student Records:
# Ali : 85
# Sara : 78
# Ahmed : 90
